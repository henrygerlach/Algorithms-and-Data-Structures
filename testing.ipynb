# %%
# %load_ext autoreload
# %autoreload 2

# %%
from helpers import *
from data_structures import *
from graph_algorithms import *
from sorting_algorithms import *
from lossless_compression import *

# %%
lz78_huffman.compress(
    from_file="lossless_compression/data/big.txt", print_statistics=True
)
